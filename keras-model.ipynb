# %% [markdown]
# <a href="https://www.kaggle.com/code/klyushnik/keras-model?scriptVersionId=180306827" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/playground-series-s4e5/sample_submission.csv
# /kaggle/input/playground-series-s4e5/train.csv
# /kaggle/input/playground-series-s4e5/test.csv

# %% [markdown]
# # previously - https://www.kaggle.com/code/klyushnik/blend-ensemble-machine-learning

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Image
# %matplotlib inline

# %% [markdown]
# # load data, make inform

# %%
train = pd.read_csv('/kaggle/input/playground-series-s4e5/train.csv')
test = pd.read_csv('/kaggle/input/playground-series-s4e5/test.csv')

print('Shape train is', train.shape, 'shape test is', test.shape)
# Out:
# Shape train is (1117957, 22) shape test is (745305, 21)

# %%
train = train.drop(columns = ['id'])
test = test.drop(columns = ['id'])

print('Shape train is', train.shape, 'shape test is', test.shape)
# Out:
# Shape train is (1117957, 21) shape test is (745305, 20)

# %%
X = train.drop(columns = ['FloodProbability'],axis =1)

y = train['FloodProbability']
X_total = test

print(f"X shape :{X.shape} , y shape :{y.shape}, X_total shape :{X_total.shape}")

X = X.astype ('int32')
X_total = X_total.astype('int32')

X_df = X.copy()
X_df_test = X_total.copy()
# Out:
# X shape :(1117957, 20) , y shape :(1117957,), X_total shape :(745305, 20)

# %% [markdown]
# # add new data

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class AggFeatureExtractor(BaseEstimator, TransformerMixin):
    
    def __init__(self, group_col, agg_col, agg_func):
        self.group_col = group_col
        self.group_col_name = ''
        for col in group_col:
            self.group_col_name += col
        self.agg_col = agg_col
        self.agg_func = agg_func
        self.agg_df = None
        self.medians = None
        
    def fit(self, X, y=None):
        group_col = self.group_col
        agg_col = self.agg_col
        agg_func = self.agg_func
        
        self.agg_df = X.groupby(group_col)[agg_col].agg(agg_func)
        self.agg_df.columns = [f'{self.group_col_name}_{agg}_{_agg_col}' for _agg_col in agg_col for agg in agg_func]
        self.medians = X[agg_col].median()
        
        return self
    
    def transform(self, X):
        group_col = self.group_col
        agg_col = self.agg_col
        agg_func = self.agg_func
        agg_df = self.agg_df
        medians = self.medians
        
        X_merged = pd.merge(X, agg_df, left_on=group_col, right_index=True, how='left')
        X_merged.fillna(medians, inplace=True)
        X_agg = X_merged.loc[:, [f'{self.group_col_name}_{agg}_{_agg_col}' for _agg_col in agg_col for agg in agg_func]]
        
        return X_agg
    
    def fit_transform(self, X, y=None):
        self.fit(X, y)
        X_agg = self.transform(X)
        return X_agg

# %%
class Preprocessor:
    def __init__(self, agg_col, agg_func, group_cols):
        self.agg_col = agg_col
        self.agg_func = agg_func
        self.group_cols = group_cols
        
    def preprocess(self, X, X_total):    
        agg_train, agg_test = [], []
        for group_col in self.group_cols:
            agg_extractor = AggFeatureExtractor(group_col=group_col, agg_col=self.agg_col, agg_func=self.agg_func)
            agg_extractor.fit(pd.concat([X, X_total], axis=0))
            agg_train.append(agg_extractor.transform(X))
            agg_test.append(agg_extractor.transform(X_total))
        X = pd.concat([X] + agg_train, axis=1)
        X_total = pd.concat([X_total] + agg_test, axis=1)
        
        X = X.fillna(0)
        X_total = X_total.fillna(0)
        return X, X_total

# %%
list_of_choice = ['MonsoonIntensity', 'TopographyDrainage', 'RiverManagement',
       'Deforestation', 'Urbanization', 'ClimateChange', 'DamsQuality',
       'Siltation', 'AgriculturalPractices', 'Encroachments',
       'IneffectiveDisasterPreparedness', 'DrainageSystems',
       'CoastalVulnerability', 'Landslides', 'Watersheds',
       'DeterioratingInfrastructure', 'PopulationScore', 'WetlandLoss',
       'InadequatePlanning', 'PoliticalFactors']

# %%
agg_col = list_of_choice

agg_func = ['mean', 'std', 'median']

group_cols = [
  ['MonsoonIntensity', 'TopographyDrainage'],
  [ 'RiverManagement', 'Deforestation'],
  ['AgriculturalPractices', 'Encroachments'],
  ['IneffectiveDisasterPreparedness', 'DrainageSystems'],
  ['CoastalVulnerability', 'Landslides'],              
  ['Watersheds', 'DeterioratingInfrastructure'],
  ['MonsoonIntensity', 'TopographyDrainage', 'RiverManagement'],
  ['CoastalVulnerability', 'Landslides', 'Watersheds'],
  ['DeterioratingInfrastructure','PopulationScore', 'WetlandLoss'],
  ['Urbanization', 'ClimateChange', 'Watersheds'], 
  ['MonsoonIntensity', 'DrainageSystems','PoliticalFactors']
             ]

pp = Preprocessor(agg_col, agg_func, group_cols)
X, X_total = pp.preprocess(X, X_total)

print(f"X shape :{X.shape} , y shape :{y.shape}, X_test shape :{X_total.shape}")
# Out:
# X shape :(1117957, 680) , y shape :(1117957,), X_test shape :(745305, 680)

# %% [markdown]
# # threshold

# %%
from sklearn.feature_selection import VarianceThreshold

def variance_threshold(df,th):
    var_thres=VarianceThreshold(threshold=th)
    var_thres.fit(df)
    new_cols = var_thres.get_support()
    return df.iloc[:,new_cols]

# %%
X = variance_threshold(X,0.01)
list_name = (X.columns)
X_total = X_total[list_name]

print(f"X shape :{X.shape} , y shape :{y.shape}, X_total shape :{X_total.shape}")
# Out:
# X shape :(1117957, 201) , y shape :(1117957,), X_total shape :(745305, 201)

# %% [markdown]
# # principal component analysis (PCA)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=1)
principalComponents = pca.fit_transform(X)
principalComponents_test = pca.fit_transform(X_total)

principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1'])
principalDftest = pd.DataFrame(data = principalComponents_test
             , columns = ['principal component 1'])

X_df['principal component_1'] = principalDf
X_df_test['principal component_1'] = principalDftest
print(f"X shape :{X_df.shape} , y shape :{y.shape}, X_test shape :{X_df_test.shape}")
# Out:
# X shape :(1117957, 21) , y shape :(1117957,), X_test shape :(745305, 21)

# %%
X = X_df
X_total = X_df_test
print(f"X shape :{X.shape} , y shape :{y.shape}, X_test shape :{X_total.shape}")
# Out:
# X shape :(1117957, 21) , y shape :(1117957,), X_test shape :(745305, 21)

# %% [markdown]
# # Keras model

# %%
from sklearn.model_selection import KFold
import keras
from keras import layers
import tensorflow as tf

# ! pip install scikeras
from sklearn.model_selection import train_test_split

from sklearn.model_selection import StratifiedKFold, KFold, StratifiedGroupKFold, RepeatedStratifiedKFold,RepeatedKFold, cross_validate
from keras.layers import BatchNormalization, Flatten, Dense, Dropout
import keras
import keras_tuner
from tensorflow.keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import cross_val_score
from optuna.trial import TrialState
# Out:
# 2024-05-28 18:57:44.077990: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-28 18:57:44.078146: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-28 18:57:44.254202: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver() # TPU detection
except ValueError:
    tpu = None
    gpus = tf.config.experimental.list_logical_devices("GPU")
    
if tpu:
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu,) 
    print('Running on TPU ', tpu.cluster_spec().as_dict()['worker'])
elif len(gpus) > 1:
    strategy = tf.distribute.MirroredStrategy([gpu.name for gpu in gpus])
    print('Running on multiple GPUs ', [gpu.name for gpu in gpus])
elif len(gpus) == 1:
    strategy = tf.distribute.get_strategy() 
    print('Running on single GPU ', gpus[0].name)
else:
    strategy = tf.distribute.get_strategy() 
    print('Running on CPU')
print("Number of accelerators: ", strategy.num_replicas_in_sync)
# Out:
# Running on CPU
# Number of accelerators:  1

# %% [markdown]
# # learn model

# %%
input_shape = [X.shape[1]]

model = keras.Sequential([  
    layers.BatchNormalization(input_shape=input_shape),
    
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.BatchNormalization(),

    layers.Dropout(0.2),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    
    layers.Dropout(0.2),
    layers.Dense(512, activation='relu'),
    layers.BatchNormalization(),
    
    layers.Dropout(0.2),
    layers.Dense(64, activation='relu'),
    layers.BatchNormalization(),
    
    layers.Dropout(0.2),
    layers.Dense(1, activation='sigmoid'),
])
model.summary()
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/normalization/batch_normalization.py:143: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ batch_normalization             │ (None, 21)             │            84 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 21)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │         2,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 512)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 64)             │        32,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 204,245 (797.83 KB)
#  Trainable params: 202,283 (790.17 KB)
#  Non-trainable params: 1,962 (7.66 KB)

# %%
from sklearn.metrics import mean_squared_error

model = model
predictions_kears = np.zeros(len(X_total))

FOLDs = KFold(n_splits=10, shuffle=True,random_state=42)

for fold_, (trn_idx, val_idx) in enumerate(FOLDs.split(X,y)):
    X.iloc[trn_idx], y.iloc[trn_idx]
    X.iloc[val_idx], y.iloc[val_idx]

    early_stopping = keras.callbacks.EarlyStopping(monitor="mse", patience=10,
                                                   min_delta=0.001,
                                                   restore_best_weights=True,)
    reduce_lr = keras.callbacks.ReduceLROnPlateau(factor = 0.1, patience = 15, mode = 'min', verbose = 1,)
    
    model.compile(loss='mean_squared_logarithmic_error', optimizer='adam', metrics=['mse'])
    
    model.fit(X.iloc[trn_idx], y.iloc[trn_idx],
            batch_size=60,
            epochs=100, 
            validation_data=(X.iloc[val_idx], y.iloc[val_idx]),
            callbacks=[reduce_lr,early_stopping],)
    
    y_pred = model.predict(X.iloc[val_idx])  
    scores = mean_squared_error(y_pred, y.iloc[val_idx], squared = False)    #model.evaluate(X[test], y[test], verbose=0)
       
    predictions_kears = model.predict(X_total)
    
    print(scores)
# Out:
# Epoch 1/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 150s 9ms/step - loss: 0.0012 - mse: 0.0027 - val_loss: 1.7352e-04 - val_mse: 3.8703e-04 - learning_rate: 0.0010
# Epoch 2/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 148s 9ms/step - loss: 2.2386e-04 - mse: 5.0254e-04 - val_loss: 1.7256e-04 - val_mse: 3.8473e-04 - learning_rate: 0.0010
# Epoch 3/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 147s 9ms/step - loss: 2.1701e-04 - mse: 4.8726e-04 - val_loss: 1.6651e-04 - val_mse: 3.7268e-04 - learning_rate: 0.0010
# Epoch 4/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 145s 9ms/step - loss: 2.1577e-04 - mse: 4.8474e-04 - val_loss: 1.6688e-04 - val_mse: 3.7310e-04 - learning_rate: 0.0010
# Epoch 5/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 146s 9ms/step - loss: 2.1457e-04 - mse: 4.8198e-04 - val_loss: 1.6808e-04 - val_mse: 3.7586e-04 - learning_rate: 0.0010
# Epoch 6/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 146s 9ms/step - loss: 2.1452e-04 - mse: 4.8190e-04 - val_loss: 1.6914e-04 - val_mse: 3.7793e-04 - learning_rate: 0.0010
# Epoch 7/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 199s 9ms/step - loss: 2.1338e-04 - mse: 4.7914e-04 - val_loss: 1.7139e-04 - val_mse: 3.8311e-04 - learning_rate: 0.0010
# Epoch 8/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 145s 9ms/step - loss: 2.1206e-04 - mse: 4.7615e-04 - val_loss: 1.7121e-04 - val_mse: 3.8376e-04 - learning_rate: 0.0010
# Epoch 9/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 145s 9ms/step - loss: 2.1151e-04 - mse: 4.7499e-04 - val_loss: 1.7412e-04 - val_mse: 3.8774e-04 - learning_rate: 0.0010
# Epoch 10/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 145s 9ms/step - loss: 2.1055e-04 - mse: 4.7280e-04 - val_loss: 1.7230e-04 - val_mse: 3.8734e-04 - learning_rate: 0.0010
# Epoch 11/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 145s 9ms/step - loss: 2.1090e-04 - mse: 4.7352e-04 - val_loss: 1.7594e-04 - val_mse: 3.9444e-04 - learning_rate: 0.0010
# 3494/3494 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step
# 23291/23291 ━━━━━━━━━━━━━━━━━━━━ 53s 2ms/step
# 0.019672974474388812
# Epoch 1/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 160s 9ms/step - loss: 2.2298e-04 - mse: 5.0051e-04 - val_loss: 1.7086e-04 - val_mse: 3.8331e-04 - learning_rate: 0.0010
# Epoch 2/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 155s 9ms/step - loss: 2.1752e-04 - mse: 4.8839e-04 - val_loss: 1.7024e-04 - val_mse: 3.8149e-04 - learning_rate: 0.0010
# Epoch 3/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 156s 9ms/step - loss: 2.1599e-04 - mse: 4.8513e-04 - val_loss: 1.6706e-04 - val_mse: 3.7409e-04 - learning_rate: 0.0010
# Epoch 4/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 198s 9ms/step - loss: 2.1493e-04 - mse: 4.8272e-04 - val_loss: 1.6922e-04 - val_mse: 3.7797e-04 - learning_rate: 0.0010
# Epoch 5/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 151s 9ms/step - loss: 2.1346e-04 - mse: 4.7926e-04 - val_loss: 1.7134e-04 - val_mse: 3.8420e-04 - learning_rate: 0.0010
# Epoch 6/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 202s 9ms/step - loss: 2.1400e-04 - mse: 4.8055e-04 - val_loss: 1.7085e-04 - val_mse: 3.8306e-04 - learning_rate: 0.0010
# Epoch 7/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 204s 9ms/step - loss: 2.1191e-04 - mse: 4.7579e-04 - val_loss: 1.7061e-04 - val_mse: 3.8112e-04 - learning_rate: 0.0010
# Epoch 8/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 197s 9ms/step - loss: 2.1121e-04 - mse: 4.7426e-04 - val_loss: 1.7045e-04 - val_mse: 3.8133e-04 - learning_rate: 0.0010
# Epoch 9/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 154s 9ms/step - loss: 2.1080e-04 - mse: 4.7334e-04 - val_loss: 1.6760e-04 - val_mse: 3.7426e-04 - learning_rate: 0.0010
# Epoch 10/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 149s 9ms/step - loss: 2.0976e-04 - mse: 4.7091e-04 - val_loss: 1.7197e-04 - val_mse: 3.8400e-04 - learning_rate: 0.0010
# Epoch 11/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 149s 9ms/step - loss: 2.1032e-04 - mse: 4.7203e-04 - val_loss: 1.7238e-04 - val_mse: 3.8695e-04 - learning_rate: 0.0010
# 3494/3494 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step
# 23291/23291 ━━━━━━━━━━━━━━━━━━━━ 54s 2ms/step
# 0.01957832095194502
# Epoch 1/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 157s 9ms/step - loss: 2.1825e-04 - mse: 4.9019e-04 - val_loss: 1.6689e-04 - val_mse: 3.7309e-04 - learning_rate: 0.0010
# Epoch 2/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 199s 9ms/step - loss: 2.1577e-04 - mse: 4.8460e-04 - val_loss: 1.6849e-04 - val_mse: 3.7797e-04 - learning_rate: 0.0010
# Epoch 3/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 199s 9ms/step - loss: 2.1522e-04 - mse: 4.8349e-04 - val_loss: 1.7599e-04 - val_mse: 3.9507e-04 - learning_rate: 0.0010
# Epoch 4/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 146s 9ms/step - loss: 2.1373e-04 - mse: 4.8005e-04 - val_loss: 1.7858e-04 - val_mse: 3.9790e-04 - learning_rate: 0.0010
# Epoch 5/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 146s 9ms/step - loss: 2.1266e-04 - mse: 4.7760e-04 - val_loss: 1.6457e-04 - val_mse: 3.6792e-04 - learning_rate: 0.0010
# Epoch 6/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 203s 9ms/step - loss: 2.1147e-04 - mse: 4.7489e-04 - val_loss: 1.7219e-04 - val_mse: 3.8351e-04 - learning_rate: 0.0010
# Epoch 7/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 147s 9ms/step - loss: 2.1224e-04 - mse: 4.7656e-04 - val_loss: 1.7047e-04 - val_mse: 3.8137e-04 - learning_rate: 0.0010
# Epoch 8/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 147s 9ms/step - loss: 2.1139e-04 - mse: 4.7453e-04 - val_loss: 1.6802e-04 - val_mse: 3.7508e-04 - learning_rate: 0.0010
# Epoch 9/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 201s 9ms/step - loss: 2.1121e-04 - mse: 4.7421e-04 - val_loss: 1.6913e-04 - val_mse: 3.7800e-04 - learning_rate: 0.0010
# Epoch 10/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 202s 9ms/step - loss: 2.1037e-04 - mse: 4.7239e-04 - val_loss: 1.6623e-04 - val_mse: 3.7113e-04 - learning_rate: 0.0010
# Epoch 11/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 147s 9ms/step - loss: 2.1026e-04 - mse: 4.7188e-04 - val_loss: 1.6982e-04 - val_mse: 3.7931e-04 - learning_rate: 0.0010
# 3494/3494 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step
# 23291/23291 ━━━━━━━━━━━━━━━━━━━━ 53s 2ms/step
# 0.019315647943235155
# Epoch 1/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 158s 9ms/step - loss: 2.1639e-04 - mse: 4.8625e-04 - val_loss: 1.7513e-04 - val_mse: 3.9238e-04 - learning_rate: 0.0010
# Epoch 2/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 148s 9ms/step - loss: 2.1362e-04 - mse: 4.7985e-04 - val_loss: 1.7515e-04 - val_mse: 3.8955e-04 - learning_rate: 0.0010
# Epoch 3/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 149s 9ms/step - loss: 2.1276e-04 - mse: 4.7773e-04 - val_loss: 1.8102e-04 - val_mse: 4.0561e-04 - learning_rate: 0.0010
# Epoch 4/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 146s 9ms/step - loss: 2.1249e-04 - mse: 4.7719e-04 - val_loss: 1.7474e-04 - val_mse: 3.8966e-04 - learning_rate: 0.0010
# Epoch 5/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 207s 9ms/step - loss: 2.1224e-04 - mse: 4.7668e-04 - val_loss: 1.6994e-04 - val_mse: 3.8074e-04 - learning_rate: 0.0010
# Epoch 6/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 195s 9ms/step - loss: 2.1097e-04 - mse: 4.7368e-04 - val_loss: 1.7058e-04 - val_mse: 3.8229e-04 - learning_rate: 0.0010
# Epoch 7/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 144s 9ms/step - loss: 2.1094e-04 - mse: 4.7371e-04 - val_loss: 1.7258e-04 - val_mse: 3.8449e-04 - learning_rate: 0.0010
# Epoch 8/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 144s 9ms/step - loss: 2.1048e-04 - mse: 4.7254e-04 - val_loss: 1.6813e-04 - val_mse: 3.7571e-04 - learning_rate: 0.0010
# Epoch 9/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 211s 9ms/step - loss: 2.1093e-04 - mse: 4.7358e-04 - val_loss: 1.7024e-04 - val_mse: 3.8160e-04 - learning_rate: 0.0010
# Epoch 10/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 199s 9ms/step - loss: 2.1055e-04 - mse: 4.7264e-04 - val_loss: 1.6977e-04 - val_mse: 3.7856e-04 - learning_rate: 0.0010
# Epoch 11/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 148s 9ms/step - loss: 2.0936e-04 - mse: 4.7008e-04 - val_loss: 1.6909e-04 - val_mse: 3.7915e-04 - learning_rate: 0.0010
# 3494/3494 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step
# 23291/23291 ━━━━━━━━━━━━━━━━━━━━ 52s 2ms/step
# 0.01980850557951688
# Epoch 1/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 152s 9ms/step - loss: 2.1441e-04 - mse: 4.8168e-04 - val_loss: 1.6876e-04 - val_mse: 3.7716e-04 - learning_rate: 0.0010
# Epoch 2/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 146s 9ms/step - loss: 2.1368e-04 - mse: 4.7991e-04 - val_loss: 1.8570e-04 - val_mse: 4.1384e-04 - learning_rate: 0.0010
# Epoch 3/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 147s 9ms/step - loss: 2.1256e-04 - mse: 4.7737e-04 - val_loss: 1.8161e-04 - val_mse: 4.0515e-04 - learning_rate: 0.0010
# Epoch 4/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 149s 9ms/step - loss: 2.1213e-04 - mse: 4.7632e-04 - val_loss: 1.6994e-04 - val_mse: 3.8072e-04 - learning_rate: 0.0010
# Epoch 5/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 199s 9ms/step - loss: 2.1221e-04 - mse: 4.7652e-04 - val_loss: 1.6771e-04 - val_mse: 3.7535e-04 - learning_rate: 0.0010
# Epoch 6/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 203s 9ms/step - loss: 2.1091e-04 - mse: 4.7365e-04 - val_loss: 1.6722e-04 - val_mse: 3.7436e-04 - learning_rate: 0.0010
# Epoch 7/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 145s 9ms/step - loss: 2.1076e-04 - mse: 4.7325e-04 - val_loss: 1.6922e-04 - val_mse: 3.7740e-04 - learning_rate: 0.0010
# Epoch 8/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 143s 9ms/step - loss: 2.1013e-04 - mse: 4.7179e-04 - val_loss: 1.7115e-04 - val_mse: 3.8165e-04 - learning_rate: 0.0010
# Epoch 9/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 206s 9ms/step - loss: 2.0979e-04 - mse: 4.7092e-04 - val_loss: 1.7105e-04 - val_mse: 3.8205e-04 - learning_rate: 0.0010
# Epoch 10/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 201s 9ms/step - loss: 2.0922e-04 - mse: 4.6973e-04 - val_loss: 1.6799e-04 - val_mse: 3.7559e-04 - learning_rate: 0.0010
# Epoch 11/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 145s 9ms/step - loss: 2.1048e-04 - mse: 4.7236e-04 - val_loss: 1.6973e-04 - val_mse: 3.7869e-04 - learning_rate: 0.0010
# 3494/3494 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step
# 23291/23291 ━━━━━━━━━━━━━━━━━━━━ 50s 2ms/step
# 0.019420629918350092
# Epoch 1/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 152s 9ms/step - loss: 2.1303e-04 - mse: 4.7842e-04 - val_loss: 1.7369e-04 - val_mse: 3.8644e-04 - learning_rate: 0.0010
# Epoch 2/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 148s 9ms/step - loss: 2.1254e-04 - mse: 4.7726e-04 - val_loss: 1.7504e-04 - val_mse: 3.9102e-04 - learning_rate: 0.0010
# Epoch 3/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 146s 9ms/step - loss: 2.1186e-04 - mse: 4.7577e-04 - val_loss: 1.6729e-04 - val_mse: 3.7438e-04 - learning_rate: 0.0010
# Epoch 4/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 146s 9ms/step - loss: 2.1213e-04 - mse: 4.7623e-04 - val_loss: 1.7990e-04 - val_mse: 4.0361e-04 - learning_rate: 0.0010
# Epoch 5/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 145s 9ms/step - loss: 2.1070e-04 - mse: 4.7310e-04 - val_loss: 1.6689e-04 - val_mse: 3.7280e-04 - learning_rate: 0.0010
# Epoch 6/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 146s 9ms/step - loss: 2.1016e-04 - mse: 4.7182e-04 - val_loss: 1.6903e-04 - val_mse: 3.7731e-04 - learning_rate: 0.0010
# Epoch 7/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 149s 9ms/step - loss: 2.1078e-04 - mse: 4.7317e-04 - val_loss: 1.6630e-04 - val_mse: 3.7154e-04 - learning_rate: 0.0010
# Epoch 8/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 147s 9ms/step - loss: 2.0980e-04 - mse: 4.7104e-04 - val_loss: 1.7244e-04 - val_mse: 3.8575e-04 - learning_rate: 0.0010
# Epoch 9/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 148s 9ms/step - loss: 2.1022e-04 - mse: 4.7198e-04 - val_loss: 1.7040e-04 - val_mse: 3.8084e-04 - learning_rate: 0.0010
# Epoch 10/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 148s 9ms/step - loss: 2.0990e-04 - mse: 4.7119e-04 - val_loss: 1.6640e-04 - val_mse: 3.7249e-04 - learning_rate: 0.0010
# Epoch 11/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 149s 9ms/step - loss: 2.1015e-04 - mse: 4.7183e-04 - val_loss: 1.6547e-04 - val_mse: 3.7038e-04 - learning_rate: 0.0010
# 3494/3494 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step
# 23291/23291 ━━━━━━━━━━━━━━━━━━━━ 53s 2ms/step
# 0.01965801547909176
# Epoch 1/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 152s 9ms/step - loss: 2.1295e-04 - mse: 4.7826e-04 - val_loss: 1.6693e-04 - val_mse: 3.7374e-04 - learning_rate: 0.0010
# Epoch 2/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 201s 9ms/step - loss: 2.1272e-04 - mse: 4.7772e-04 - val_loss: 1.6512e-04 - val_mse: 3.6888e-04 - learning_rate: 0.0010
# Epoch 3/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 147s 9ms/step - loss: 2.1117e-04 - mse: 4.7408e-04 - val_loss: 1.7391e-04 - val_mse: 3.8928e-04 - learning_rate: 0.0010
# Epoch 4/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 147s 9ms/step - loss: 2.1165e-04 - mse: 4.7504e-04 - val_loss: 1.6861e-04 - val_mse: 3.7644e-04 - learning_rate: 0.0010
# Epoch 5/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 146s 9ms/step - loss: 2.1095e-04 - mse: 4.7357e-04 - val_loss: 1.6637e-04 - val_mse: 3.7195e-04 - learning_rate: 0.0010
# Epoch 6/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 148s 9ms/step - loss: 2.1093e-04 - mse: 4.7352e-04 - val_loss: 1.6842e-04 - val_mse: 3.7787e-04 - learning_rate: 0.0010
# Epoch 7/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 145s 9ms/step - loss: 2.0954e-04 - mse: 4.7043e-04 - val_loss: 1.6917e-04 - val_mse: 3.7868e-04 - learning_rate: 0.0010
# Epoch 8/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 147s 9ms/step - loss: 2.1082e-04 - mse: 4.7324e-04 - val_loss: 1.6956e-04 - val_mse: 3.7795e-04 - learning_rate: 0.0010
# Epoch 9/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 147s 9ms/step - loss: 2.1073e-04 - mse: 4.7303e-04 - val_loss: 1.6623e-04 - val_mse: 3.7201e-04 - learning_rate: 0.0010
# Epoch 10/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 146s 9ms/step - loss: 2.0889e-04 - mse: 4.6893e-04 - val_loss: 1.7140e-04 - val_mse: 3.8510e-04 - learning_rate: 0.0010
# Epoch 11/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 147s 9ms/step - loss: 2.0906e-04 - mse: 4.6933e-04 - val_loss: 1.7005e-04 - val_mse: 3.8128e-04 - learning_rate: 0.0010
# 3494/3494 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step
# 23291/23291 ━━━━━━━━━━━━━━━━━━━━ 50s 2ms/step
# 0.01933240319379689
# Epoch 1/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 152s 9ms/step - loss: 2.1268e-04 - mse: 4.7753e-04 - val_loss: 1.6846e-04 - val_mse: 3.7699e-04 - learning_rate: 0.0010
# Epoch 2/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 202s 9ms/step - loss: 2.1163e-04 - mse: 4.7516e-04 - val_loss: 1.6591e-04 - val_mse: 3.7128e-04 - learning_rate: 0.0010
# Epoch 3/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 197s 9ms/step - loss: 2.1158e-04 - mse: 4.7524e-04 - val_loss: 1.7656e-04 - val_mse: 3.9494e-04 - learning_rate: 0.0010
# Epoch 4/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 146s 9ms/step - loss: 2.1019e-04 - mse: 4.7196e-04 - val_loss: 1.6985e-04 - val_mse: 3.7953e-04 - learning_rate: 0.0010
# Epoch 5/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 152s 9ms/step - loss: 2.1116e-04 - mse: 4.7411e-04 - val_loss: 1.6751e-04 - val_mse: 3.7512e-04 - learning_rate: 0.0010
# Epoch 6/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 146s 9ms/step - loss: 2.0995e-04 - mse: 4.7135e-04 - val_loss: 1.7524e-04 - val_mse: 3.9373e-04 - learning_rate: 0.0010
# Epoch 7/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 147s 9ms/step - loss: 2.1008e-04 - mse: 4.7148e-04 - val_loss: 1.6642e-04 - val_mse: 3.7259e-04 - learning_rate: 0.0010
# Epoch 8/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 144s 9ms/step - loss: 2.0982e-04 - mse: 4.7089e-04 - val_loss: 1.8585e-04 - val_mse: 4.1882e-04 - learning_rate: 0.0010
# Epoch 9/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 149s 9ms/step - loss: 2.0951e-04 - mse: 4.7026e-04 - val_loss: 1.7163e-04 - val_mse: 3.8318e-04 - learning_rate: 0.0010
# Epoch 10/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 148s 9ms/step - loss: 2.0992e-04 - mse: 4.7131e-04 - val_loss: 1.6926e-04 - val_mse: 3.7889e-04 - learning_rate: 0.0010
# Epoch 11/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 204s 9ms/step - loss: 2.0877e-04 - mse: 4.6850e-04 - val_loss: 1.7236e-04 - val_mse: 3.8405e-04 - learning_rate: 0.0010
# 3494/3494 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step
# 23291/23291 ━━━━━━━━━━━━━━━━━━━━ 50s 2ms/step
# 0.01941619291208678
# Epoch 1/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 152s 9ms/step - loss: 2.1122e-04 - mse: 4.7429e-04 - val_loss: 1.7274e-04 - val_mse: 3.8708e-04 - learning_rate: 0.0010
# Epoch 2/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 200s 9ms/step - loss: 2.1083e-04 - mse: 4.7330e-04 - val_loss: 1.7622e-04 - val_mse: 3.9405e-04 - learning_rate: 0.0010
# Epoch 3/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 199s 9ms/step - loss: 2.1081e-04 - mse: 4.7323e-04 - val_loss: 1.7265e-04 - val_mse: 3.8515e-04 - learning_rate: 0.0010
# Epoch 4/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 148s 9ms/step - loss: 2.0963e-04 - mse: 4.7047e-04 - val_loss: 1.6678e-04 - val_mse: 3.7347e-04 - learning_rate: 0.0010
# Epoch 5/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 143s 9ms/step - loss: 2.1050e-04 - mse: 4.7265e-04 - val_loss: 1.6912e-04 - val_mse: 3.7943e-04 - learning_rate: 0.0010
# Epoch 6/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 205s 9ms/step - loss: 2.0945e-04 - mse: 4.7012e-04 - val_loss: 1.6759e-04 - val_mse: 3.7505e-04 - learning_rate: 0.0010
# Epoch 7/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 144s 9ms/step - loss: 2.0967e-04 - mse: 4.7061e-04 - val_loss: 1.6825e-04 - val_mse: 3.7662e-04 - learning_rate: 0.0010
# Epoch 8/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 202s 9ms/step - loss: 2.0963e-04 - mse: 4.7043e-04 - val_loss: 1.6560e-04 - val_mse: 3.7086e-04 - learning_rate: 0.0010
# Epoch 9/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 149s 9ms/step - loss: 2.0932e-04 - mse: 4.6962e-04 - val_loss: 1.6880e-04 - val_mse: 3.7839e-04 - learning_rate: 0.0010
# Epoch 10/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 145s 9ms/step - loss: 2.0993e-04 - mse: 4.7117e-04 - val_loss: 1.6810e-04 - val_mse: 3.7601e-04 - learning_rate: 0.0010
# Epoch 11/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 148s 9ms/step - loss: 2.0897e-04 - mse: 4.6898e-04 - val_loss: 1.7451e-04 - val_mse: 3.9263e-04 - learning_rate: 0.0010
# 3494/3494 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step
# 23291/23291 ━━━━━━━━━━━━━━━━━━━━ 50s 2ms/step
# 0.019674410892138703
# Epoch 1/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 153s 9ms/step - loss: 2.1156e-04 - mse: 4.7496e-04 - val_loss: 1.7726e-04 - val_mse: 3.9733e-04 - learning_rate: 0.0010
# Epoch 2/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 143s 8ms/step - loss: 2.1035e-04 - mse: 4.7225e-04 - val_loss: 1.7051e-04 - val_mse: 3.8040e-04 - learning_rate: 0.0010
# Epoch 3/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 147s 9ms/step - loss: 2.1016e-04 - mse: 4.7167e-04 - val_loss: 1.6851e-04 - val_mse: 3.7745e-04 - learning_rate: 0.0010
# Epoch 4/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 143s 8ms/step - loss: 2.1064e-04 - mse: 4.7281e-04 - val_loss: 1.7104e-04 - val_mse: 3.8195e-04 - learning_rate: 0.0010
# Epoch 5/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 149s 9ms/step - loss: 2.0913e-04 - mse: 4.6934e-04 - val_loss: 1.6651e-04 - val_mse: 3.7227e-04 - learning_rate: 0.0010
# Epoch 6/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 141s 8ms/step - loss: 2.0944e-04 - mse: 4.7003e-04 - val_loss: 1.6538e-04 - val_mse: 3.6974e-04 - learning_rate: 0.0010
# Epoch 7/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 147s 9ms/step - loss: 2.0804e-04 - mse: 4.6690e-04 - val_loss: 1.6517e-04 - val_mse: 3.6971e-04 - learning_rate: 0.0010
# Epoch 8/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 205s 9ms/step - loss: 2.0936e-04 - mse: 4.6983e-04 - val_loss: 1.7560e-04 - val_mse: 3.9053e-04 - learning_rate: 0.0010
# Epoch 9/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 151s 9ms/step - loss: 2.1015e-04 - mse: 4.7155e-04 - val_loss: 1.6772e-04 - val_mse: 3.7631e-04 - learning_rate: 0.0010
# Epoch 10/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 148s 9ms/step - loss: 2.0844e-04 - mse: 4.6781e-04 - val_loss: 1.6518e-04 - val_mse: 3.6965e-04 - learning_rate: 0.0010
# Epoch 11/100
# 16770/16770 ━━━━━━━━━━━━━━━━━━━━ 146s 9ms/step - loss: 2.0967e-04 - mse: 4.7059e-04 - val_loss: 1.6877e-04 - val_mse: 3.7845e-04 - learning_rate: 0.0010
# 3494/3494 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step
# 23291/23291 ━━━━━━━━━━━━━━━━━━━━ 50s 2ms/step
# 0.01993317732326855

# %% [markdown]
# # submit

# %%
sample = pd.read_csv('/kaggle/input/playground-series-s4e5/sample_submission.csv')
sample['FloodProbability'] = predictions_kears
sample.to_csv('submission.csv', index=False)
sample
# Out:
#              id  FloodProbability
# 0       1117957          0.567630
# 1       1117958          0.459383
# 2       1117959          0.456270
# 3       1117960          0.472237
# 4       1117961          0.472729
# ...         ...               ...
# 745300  1863257          0.477891
# 745301  1863258          0.452323
# 745302  1863259          0.611864
# 745303  1863260          0.546028
# 745304  1863261          0.510043
#
# [745305 rows x 2 columns]
